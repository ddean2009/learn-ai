# %% [markdown]
# # 一个简单的例子

# %%
import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots()
ax.plot([5, 2, 3, 4], [1, 4, 2, 3])

# %% [markdown]
# # 面向对象

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.rcParams['font.sans-serif'] = ['Arial Unicode MS'] #用来正常显示中文标签
plt.rcParams['axes.unicode_minus']=False #用来正常显示负号

x = np.linspace(1, 4, 100)

fig, ax = plt.subplots()  # 创建figure和axes
ax.plot(x, x, label='线性')
ax.plot(x, x**2, label='二次方')
ax.plot(x, x**3, label='三次方')
ax.set_xlabel('x轴')
ax.set_ylabel('y轴')
ax.set_title("这是一个图像呀")
ax.legend()

# %% [markdown]
# # 使用pyplot

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.rcParams['font.sans-serif'] = ['Arial Unicode MS'] #用来正常显示中文标签
plt.rcParams['axes.unicode_minus']=False #用来正常显示负号

x = np.linspace(1, 4, 100)

plt.plot(x, x, label='线性')
plt.plot(x, x**2, label='二次方')
plt.plot(x, x**3, label='三次方')
plt.xlabel('x轴')
plt.ylabel('y轴')
plt.title("这是一个图像呀")
plt.legend()

# %% [markdown]
# # 线段简化

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

# Setup, and create the data to plot
y = np.random.rand(100000)
y[50000:] *= 2
y[np.geomspace(10, 50000, 400).astype(int)] = -1
mpl.rcParams['path.simplify'] = True

mpl.rcParams['path.simplify_threshold'] = 0.0
plt.plot(y)
plt.show()

mpl.rcParams['path.simplify_threshold'] = 1.0
plt.plot(y)
plt.show()
